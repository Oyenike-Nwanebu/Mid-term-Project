# %% [markdown]
# # Clustering
# In this file, instructions how to approach the challenge can be found.
#
# We can use different types of clustering algorithms:
#
# - KMeans
# - Hierarchical
# - DBScan

# %%
#import libraries
import pandas as pd
import numpy as np
# import matplotlib
import matplotlib.pyplot as plt

# import Kmeans from sklearn
from sklearn.cluster import KMeans

from sklearn.preprocessing import StandardScaler

import folium  ## map rendering library

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
from geopy.geocoders import Nominatim

# import scipy.cluster.hierarchy
import scipy.cluster.hierarchy as sch

# aglomerative clustering
from sklearn.cluster import AgglomerativeClustering

# import DBSCAN
from sklearn.cluster import DBSCAN

import plotly.graph_objects as go

from sklearn import metrics

# %%
#load dataset
NYC_covid = pd.read_csv('NYC_covid.csv')

#check data
NYC_covid.head()
# Out:
#   Neighbourhood borough  longitude   latitude  Population  ZIP_CODE  MODZCTA  \
# 0     Wakefield   Bronx -73.847201  40.894705     29158.0     10466    10466
# 1    Co-op City   Bronx -73.829939  40.874294     43752.0     10475    10475
# 2     Fieldston   Bronx -73.905643  40.895437      3292.0     10471    10471
# 3     Riverdale   Bronx -73.912585  40.890834     48049.0     10463    10463
# 4   Kingsbridge   Bronx -73.902818  40.881687     10669.0     10463    10463
#
#    COVID_CONFIRMED_CASE_RATE  COVID_CONFIRMED_DEATH_RATE  TOTAL_COVID_TESTS  \
# 0                   21299.93                      388.44              65398
# 1                   19781.32                      669.20              37537
# 2                   21453.73                      640.27              23352
# 3                   21106.29                      508.69              66378
# 4                   21106.29                      508.69              66378
#
#    COVID_CONFIRMED_CASE_COUNT  COVID_CONFIRMED_DEATH_COUNT
# 0                      6210.0                        113.0
# 1                      8654.0                        292.0
# 2                       706.0                         21.0
# 3                     10141.0                        244.0
# 4                      2251.0                         54.0

# %%
#drop Neighbourhood, borough, longitude, latitude, Population, ZIP_CODE, MODZCTA, COVID_CONFIRMED_CASE_RATE, COVID_CONFIRMED_DEATH_RATE columns
covid = NYC_covid.drop(['Neighbourhood', 'borough', 'longitude', 'latitude', 'Population', 
            'ZIP_CODE', 'MODZCTA', 'COVID_CONFIRMED_CASE_RATE', 'COVID_CONFIRMED_DEATH_RATE', 'TOTAL_COVID_TESTS'], axis=1)

#check
covid.head()
# Out:
#    COVID_CONFIRMED_CASE_COUNT  COVID_CONFIRMED_DEATH_COUNT
# 0                      6210.0                        113.0
# 1                      8654.0                        292.0
# 2                       706.0                         21.0
# 3                     10141.0                        244.0
# 4                      2251.0                         54.0

# %%
#standardize using StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(covid)

# %%
###Elbow Rule --Used to determine k - number of clusters -- aim for small inertia/distortion

#define function to calculate the distortion(inertia) for multiple k values and plot the results
def plot_distortion(X,max_clusters = 10):
    distortions = []
    for i in range(1, max_clusters +1):
        km = KMeans(n_clusters=i,
                    init='k-means++',
                    n_init=10,
                    random_state=0)
        km.fit(X)
        distortions.append(km.inertia_)
        
    plt.plot(range(1,max_clusters +1), distortions, marker='o')
    plt.xlabel('Number of clusters')
    plt.ylabel('Distortion')
    plt.show()

# %%
# elbow rule
plot_distortion(scaled_data,max_clusters=10)

# %%
##K-Means Clustering

km = KMeans(n_clusters=3, # how many clusters from elbow rule
            n_init=10, # how many initial runs
            random_state=0) #For reproducibility

# %%
## fit and predict 
X = scaled_data

y_km = km.fit_predict(X)

# %%
#make a deep copy of the NYC_covid dataframe
NYC_kmeans_df = NYC_covid.copy()

#get the cluster each neighborhood belongs to
NYC_kmeans_df['cluster'] = y_km

#check dataframe
NYC_kmeans_df.head()
# Out:
#   Neighbourhood borough  longitude   latitude  Population  ZIP_CODE  MODZCTA  \
# 0     Wakefield   Bronx -73.847201  40.894705     29158.0     10466    10466
# 1    Co-op City   Bronx -73.829939  40.874294     43752.0     10475    10475
# 2     Fieldston   Bronx -73.905643  40.895437      3292.0     10471    10471
# 3     Riverdale   Bronx -73.912585  40.890834     48049.0     10463    10463
# 4   Kingsbridge   Bronx -73.902818  40.881687     10669.0     10463    10463
#
#    COVID_CONFIRMED_CASE_RATE  COVID_CONFIRMED_DEATH_RATE  TOTAL_COVID_TESTS  \
# 0                   21299.93                      388.44              65398
# 1                   19781.32                      669.20              37537
# 2                   21453.73                      640.27              23352
# 3                   21106.29                      508.69              66378
# 4                   21106.29                      508.69              66378
#
#    COVID_CONFIRMED_CASE_COUNT  COVID_CONFIRMED_DEATH_COUNT  cluster
# 0                      6210.0                        113.0        1
# 1                      8654.0                        292.0        2
# 2                       706.0                         21.0        1
# 3                     10141.0                        244.0        2
# 4                      2251.0                         54.0        1

# %%
#check neighborhoods in cluster 0
NYC_kmeans_df[NYC_kmeans_df['cluster'] == 1]
# Out:
#           Neighbourhood    borough  longitude   latitude  Population  \
# 34          Bensonhurst   Brooklyn -73.995180  40.611009    104934.0
# 35          Sunset Park   Brooklyn -74.010316  40.645103    126000.0
# 39             Flatbush   Brooklyn -73.958401  40.636326    105804.0
# 40        Crown Heights   Brooklyn -73.943291  40.670829    143000.0
# 41        East Flatbush   Brooklyn -73.936103  40.641718    135619.0
# 45         Williamsburg   Brooklyn -73.958115  40.707144    151308.0
# 46             Bushwick   Brooklyn -73.925258  40.698116    129239.0
# 56         Borough Park   Brooklyn -73.990498  40.633131    153470.0
# 65   Washington Heights  Manhattan -73.936900  40.851903    143879.0
# 69          East Harlem  Manhattan -73.944182  40.792249    115921.0
# 72      Upper West Side  Manhattan -73.977059  40.787658    214744.0
# 84      Jackson Heights     Queens -73.882821  40.751981    108152.0
# 85             Elmhurst     Queens -73.881656  40.744049     88427.0
# 87               Corona     Queens -73.856825  40.742382    109695.0
# 124        North Corona     Queens -73.857518  40.754071    109695.0
# 134               Rugby   Brooklyn -73.926882  40.655572    135619.0
# 148             Erasmus   Brooklyn -73.948177  40.646926    135619.0
# 163       East New York   Brooklyn -73.880699  40.669926     91958.0
# 170           City Line   Brooklyn -73.867976  40.678570     94469.0
# 181            Flushing     Queens -73.831773  40.764454     72008.0
# 211             Wingate   Brooklyn -73.937187  40.660947    110300.0
# 263  Bedford Stuyvesant   Brooklyn -73.941785  40.687232    157530.0
# 268          South Side   Brooklyn -73.958001  40.710861    156393.0
# 269      Central Harlem  Manhattan -73.943211  40.815976    197052.0
# 277         Lefrak City     Queens -73.862525  40.736075     91510.0
# 298   Broadway Junction   Brooklyn -73.903317  40.677861     97518.0
#
#      ZIP_CODE  MODZCTA  COVID_CONFIRMED_CASE_RATE  COVID_CONFIRMED_DEATH_RATE  \
# 34      11204    11204                   22076.22                      371.01
# 35      11220    11220                   25480.29                      353.10
# 39      11226    11226                   21553.06                      487.90
# 40      11213    11213                   23778.17                      450.46
# 41      11203    11203                   21773.36                      521.04
# 45      11206    11206                   24075.67                      350.59
# 46      11206    11206                   24075.67                      350.59
# 56      11204    11204                   22076.22                      371.01
# 65      10032    10032                   19696.72                      417.12
# 69      10029    10029                   24216.10                      484.50
# 72      10023    10023                   19372.81                      168.33
# 84      11370    11370                   24514.33                      330.42
# 85      11373    11373                   27235.62                      445.14
# 87      11368    11368                   24864.60                      529.13
# 124     11368    11368                   24864.60                      529.13
# 134     11203    11203                   21773.36                      521.04
# 148     11203    11203                   21773.36                      521.04
# 163     11207    11207                   25965.99                      463.88
# 170     11207    11207                   25965.99                      463.88
# 181     11354    11354                   21358.02                      882.81
# 211     11203    11203                   21773.36                      521.04
# 263     11205    11205                   21254.12                      211.77
# 268     11206    11206                   24075.67                      350.59
# 269     10037    10037                   22728.40                      490.54
# 277     11368    11368                   24864.60                      529.13
# 298     11207    11207                   25965.99                      463.88
#
#      TOTAL_COVID_TESTS  COVID_CONFIRMED_CASE_COUNT  \
# 34               76567                     23165.0
# 35               93606                     32105.0
# 39               95017                     22803.0
# 40               69425                     34002.0
# 41               69622                     29528.0
# 45               92227                     36428.0
# 46               92227                     31115.0
# 56               76567                     33880.0
# 65               56169                     28339.0
# 69               80986                     28071.0
# 72               72322                     41601.0
# 84               30671                     26512.0
# 85              100090                     24083.0
# 87              116077                     27275.0
# 124             116077                     27275.0
# 134              69622                     29528.0
# 148              69622                     29528.0
# 163              92331                     23877.0
# 170              92331                     24529.0
# 181              52412                     15379.0
# 211              69622                     24016.0
# 263              49349                     33481.0
# 268              92227                     37652.0
# 269              21785                     44786.0
# 277             116077                     22753.0
# 298              92331                     25321.0
#
#      COVID_CONFIRMED_DEATH_COUNT  cluster
# 34                         389.0        1
# 35                         444.0        1
# 39                         516.0        1
# 40                         644.0        1
# 41                         706.0        1
# 45                         530.0        1
# 46                         453.0        1
# 56                         569.0        1
# 65                         600.0        1
# 69                         561.0        1
# 72                         361.0        1
# 84                         357.0        1
# 85                         393.0        1
# 87                         580.0        1
# 124                        580.0        1
# 134                        706.0        1
# 148                        706.0        1
# 163                        426.0        1
# 170                        438.0        1
# 181                        635.0        1
# 211                        574.0        1
# 263                        333.0        1
# 268                        548.0        1
# 269                        966.0        1
# 277                        484.0        1
# 298                        452.0        1

# %%
#define a function to visualize neighborhood cluster on map

def neighborhood_cluster_viz(num_clusters, df, colours):
    '''This function takes an input of the num of clusters with maximum of 5 clusters, 
    a dataframe and a list of colours based on cluster interpretation and outputs a map of the neighbourhood with each circle 
    representing a neighbourhood and the colour representing the cluster the neighbourhood belongs to'''
   
    #get latitude, longitude of New York city
    latitude = 40.7127281
    longitude  = -74.0060152

    map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

    # set color scheme for the clusters
    num_clusters = num_clusters
    colours = colours
    #colours = ['red', 'green','yellow' , 'purple', 'pink']

    # add neighborhood cluster markers to the map
    markers_colors = []
    for lat, lon, bor, nei, cluster, case_count, death_count in zip(
        df['latitude'], df['longitude'], df['borough'], df['Neighbourhood'], 
        df['cluster'],df['COVID_CONFIRMED_CASE_COUNT'], df['COVID_CONFIRMED_DEATH_COUNT']):

            label = folium.Popup(('Cluster' + " " + str(cluster)+': ' + str(bor) + "-" + str(nei) + " " + str(case_count) + " " + "cases" + " " + str(death_count) + " " + "deaths"), parse_html=True)
            folium.CircleMarker([lat, lon],
                radius=5,
                popup=label,
                color=colours[cluster],
                fill=True,
                fill_color=colours[cluster],
                fill_opacity=0.7).add_to(map_clusters)
    return map_clusters

# %% [markdown]
# ## visualize covid case count and death counts clustering by kmeans

# %%
neighborhood_cluster_viz(num_clusters = 3, df = NYC_kmeans_df, colours = ['red', 'green', 'yellow'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ea23afe45c039dac1fe49706e287cfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ea23afe45c039dac1fe49706e287cfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7ea23afe45c039dac1fe49706e287cfc = L.map(
#                 &quot;map_7ea23afe45c039dac1fe49706e287cfc&quot;,
#                 {
#                     center: [40.7127281, -74.0060152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf710949d7754a0dc0db2cce9379a538 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7ea23afe45c039dac1fe49706e287cfc);
#
#
#             var circle_marker_7b52ac937593ee8175d0f4f56b35b881 = L.circleMarker(
#                 [40.89470517661, -73.847200520549],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ea23afe45c039dac1fe49706e287cfc);
#
#
#         var popup_fd947b90b7389ad9e7915284c927338c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bdd5dee5027982b06e7232b29f1c72d4 = $(`&lt;div id=&quot;html_bdd5dee5027982b06e7232b29f1c72d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1: Bronx-Wakefield 6210.0 cases 113.0 deaths&lt;/div&gt;`)[0];
#             popup_fd947b90b7389ad9e7915284c927338c.setContent(html_bdd5dee5027982b06e7232b29f1c72d4);
#
#
#         circle_marker_7b52ac937593ee8175d0f4f56b35b881.bindPopup(popup_fd947b90b7389ad9e7915284c927338c)
#         ;
#
#
#
#
#             var circle_marker_55feed19d34b0b124e30e1e453a1abff = L.circleMarker(
#                 [40.8742941930301, -73.829939108124],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ea23afe45c039dac1fe49706e287cfc);
#
#
#         var popup_fbdbb89bd5970bf33b470fac5c8baf73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_968f713e5e7586fe0568bf922c4b8a1b = $(`&lt;div id=&quot;html_968f713e5e7586fe0568bf922c4b8a1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 2: Bronx-Co-op City 8654.0 cases 292.0 deaths&lt;/div&gt;`)[0];
#             popup_fbdbb89bd5970bf33b470fac5c8baf73.setContent(html_968f713e5e7586fe0568bf922c4b8a1b);
#
#
#         circle_marker_55feed19d34b0b124e30e1e453a1abff.bindPopup(popup_fbdbb89bd5970bf33b470fac5c8baf73)
#         ;
#
#
#
#
#             var circle_marker_1d0d4e7269295ff58b2d30196db5fe04 = L.circleMarker(
#                 [40.8954374269038, -73.9056425959168],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7ea23afe45c039dac1fe49706e287cfc);
#
#
#         var popup_0e1e20dd1d0c86a18a93c34dbc07a45a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6bdf290f1cd3ee9c23e1e7da4c8e1c11 = $(`&lt;div id=&quot;html_6bdf290f1cd3ee9c23e1e7da4c8e1c11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1: Bronx-Fieldston 706.0 cases 21.0 deaths&lt;/div&gt;`)[0];
#             popup_0e1e20dd1d0c86a18a93c34dbc07a45a.setContent(html_6bdf290f1cd3ee9c23e1e7da4c8e1c11);
#
#
#         circle_marker_1d0d4e7269295ff58b2d30196db5fe04.bindPopup(popup_0e1e20dd1d0c86a18a93c34dbc07a45a)
#         ;
#
#
#
#
#             var circle_marker_a25c3fb7f8f26b948ecf6cfbe0dd9d2e = L.circleMarker(
#                 [40.8908344938913, -73.9125854610857],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpa

# %% [markdown]
# ### use hierachical clustering

# %%
#define a function to plot dendogram
def plot_dendrogram(X,method ='ward'):
    dendrogram = sch.dendrogram(sch.linkage(X, method=method))
    plt.title("Dendrogram")
    plt.ylabel("Euclidean distances")
    plt.xlabel('Points')
    plt.show()

# %%
#Convert dataframe to array
X1 = covid.to_numpy()

#plot dendogram

plot_dendrogram(X)

# %%
##From dendrogram, optimal number of clusters = 3

#create an object from the AgglomerativeClustering class

ac = AgglomerativeClustering(affinity='euclidean',  #set the Euclidean distance to the affinity parameter
                             linkage='ward',  #linkage determines the metric used for the merge strategy
                             n_clusters = 3)  #number of clusters

# fit and predict
y_hc = ac.fit_predict(X)

# %%
#Define function to plot the clusters
def plot_clusters(X,y_res, plt_cluster_centers = False):
    X_centroids = []
    Y_centroids = []

    for cluster in set(y_res):
        x = X[y_res == cluster,0]
        y = X[y_res == cluster,1]
        X_centroids.append(np.mean(x))
        Y_centroids.append(np.mean(y))

        plt.scatter(x,
                    y,
                    s=50,
                    marker='s',
                    label=f'cluster {cluster}')

    if plt_cluster_centers:
        plt.scatter(X_centroids,
                    Y_centroids,
                    marker='*',
                    c='red',
                    s=250,
                    label='centroids')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Plot clustering result
plot_clusters(X,y_hc)

# %%
#visualize neighborhood clusters from hierachical clustering in map
#make a deep copy of the NYC_covid dataframe
NYC_hierarchical_df = NYC_covid.copy()

#get the cluster each neighborhood belongs to
NYC_hierarchical_df['cluster'] = y_hc

#check dataframe
NYC_hierarchical_df.head()
# Out:
#   Neighbourhood borough  longitude   latitude  Population  ZIP_CODE  MODZCTA  \
# 0     Wakefield   Bronx -73.847201  40.894705     29158.0     10466    10466
# 1    Co-op City   Bronx -73.829939  40.874294     43752.0     10475    10475
# 2     Fieldston   Bronx -73.905643  40.895437      3292.0     10471    10471
# 3     Riverdale   Bronx -73.912585  40.890834     48049.0     10463    10463
# 4   Kingsbridge   Bronx -73.902818  40.881687     10669.0     10463    10463
#
#    COVID_CONFIRMED_CASE_RATE  COVID_CONFIRMED_DEATH_RATE  TOTAL_COVID_TESTS  \
# 0                   21299.93                      388.44              65398
# 1                   19781.32                      669.20              37537
# 2                   21453.73                      640.27              23352
# 3                   21106.29                      508.69              66378
# 4                   21106.29                      508.69              66378
#
#    COVID_CONFIRMED_CASE_COUNT  COVID_CONFIRMED_DEATH_COUNT  cluster
# 0                      6210.0                        113.0        0
# 1                      8654.0                        292.0        2
# 2                       706.0                         21.0        0
# 3                     10141.0                        244.0        2
# 4                      2251.0                         54.0        0

# %%
NYC_hierarchical_df[NYC_hierarchical_df['cluster'] == 1]
# Out:
#           Neighbourhood    borough  longitude   latitude  Population  \
# 34          Bensonhurst   Brooklyn -73.995180  40.611009    104934.0
# 35          Sunset Park   Brooklyn -74.010316  40.645103    126000.0
# 39             Flatbush   Brooklyn -73.958401  40.636326    105804.0
# 40        Crown Heights   Brooklyn -73.943291  40.670829    143000.0
# 41        East Flatbush   Brooklyn -73.936103  40.641718    135619.0
# 45         Williamsburg   Brooklyn -73.958115  40.707144    151308.0
# 46             Bushwick   Brooklyn -73.925258  40.698116    129239.0
# 56         Borough Park   Brooklyn -73.990498  40.633131    153470.0
# 65   Washington Heights  Manhattan -73.936900  40.851903    143879.0
# 69          East Harlem  Manhattan -73.944182  40.792249    115921.0
# 72      Upper West Side  Manhattan -73.977059  40.787658    214744.0
# 84      Jackson Heights     Queens -73.882821  40.751981    108152.0
# 85             Elmhurst     Queens -73.881656  40.744049     88427.0
# 87               Corona     Queens -73.856825  40.742382    109695.0
# 124        North Corona     Queens -73.857518  40.754071    109695.0
# 134               Rugby   Brooklyn -73.926882  40.655572    135619.0
# 148             Erasmus   Brooklyn -73.948177  40.646926    135619.0
# 163       East New York   Brooklyn -73.880699  40.669926     91958.0
# 170           City Line   Brooklyn -73.867976  40.678570     94469.0
# 181            Flushing     Queens -73.831773  40.764454     72008.0
# 211             Wingate   Brooklyn -73.937187  40.660947    110300.0
# 263  Bedford Stuyvesant   Brooklyn -73.941785  40.687232    157530.0
# 268          South Side   Brooklyn -73.958001  40.710861    156393.0
# 269      Central Harlem  Manhattan -73.943211  40.815976    197052.0
# 277         Lefrak City     Queens -73.862525  40.736075     91510.0
# 298   Broadway Junction   Brooklyn -73.903317  40.677861     97518.0
#
#      ZIP_CODE  MODZCTA  COVID_CONFIRMED_CASE_RATE  COVID_CONFIRMED_DEATH_RATE  \
# 34      11204    11204                   22076.22                      371.01
# 35      11220    11220                   25480.29                      353.10
# 39      11226    11226                   21553.06                      487.90
# 40      11213    11213                   23778.17                      450.46
# 41      11203    11203                   21773.36                      521.04
# 45      11206    11206                   24075.67                      350.59
# 46      11206    11206                   24075.67                      350.59
# 56      11204    11204                   22076.22                      371.01
# 65      10032    10032                   19696.72                      417.12
# 69      10029    10029                   24216.10                      484.50
# 72      10023    10023                   19372.81                      168.33
# 84      11370    11370                   24514.33                      330.42
# 85      11373    11373                   27235.62                      445.14
# 87      11368    11368                   24864.60                      529.13
# 124     11368    11368                   24864.60                      529.13
# 134     11203    11203                   21773.36                      521.04
# 148     11203    11203                   21773.36                      521.04
# 163     11207    11207                   25965.99                      463.88
# 170     11207    11207                   25965.99                      463.88
# 181     11354    11354                   21358.02                      882.81
# 211     11203    11203                   21773.36                      521.04
# 263     11205    11205                   21254.12                      211.77
# 268     11206    11206                   24075.67                      350.59
# 269     10037    10037                   22728.40                      490.54
# 277     11368    11368                   24864.60                      529.13
# 298     11207    11207                   25965.99                      463.88
#
#      TOTAL_COVID_TESTS  COVID_CONFIRMED_CASE_COUNT  \
# 34               76567                     23165.0
# 35               93606                     32105.0
# 39               95017                     22803.0
# 40               69425                     34002.0
# 41               69622                     29528.0
# 45               92227                     36428.0
# 46               92227                     31115.0
# 56               76567                     33880.0
# 65               56169                     28339.0
# 69               80986                     28071.0
# 72               72322                     41601.0
# 84               30671                     26512.0
# 85              100090                     24083.0
# 87              116077                     27275.0
# 124             116077                     27275.0
# 134              69622                     29528.0
# 148              69622                     29528.0
# 163              92331                     23877.0
# 170              92331                     24529.0
# 181              52412                     15379.0
# 211              69622                     24016.0
# 263              49349                     33481.0
# 268              92227                     37652.0
# 269              21785                     44786.0
# 277             116077                     22753.0
# 298              92331                     25321.0
#
#      COVID_CONFIRMED_DEATH_COUNT  cluster
# 34                         389.0        1
# 35                         444.0        1
# 39                         516.0        1
# 40                         644.0        1
# 41                         706.0        1
# 45                         530.0        1
# 46                         453.0        1
# 56                         569.0        1
# 65                         600.0        1
# 69                         561.0        1
# 72                         361.0        1
# 84                         357.0        1
# 85                         393.0        1
# 87                         580.0        1
# 124                        580.0        1
# 134                        706.0        1
# 148                        706.0        1
# 163                        426.0        1
# 170                        438.0        1
# 181                        635.0        1
# 211                        574.0        1
# 263                        333.0        1
# 268                        548.0        1
# 269                        966.0        1
# 277                        484.0        1
# 298                        452.0        1

# %% [markdown]
# ## visualize neighborhood clustering by hierarchical clustering method

# %%
neighborhood_cluster_viz(num_clusters = 4, df = NYC_hierarchical_df, colours=['green', 'red', 'yellow'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4eeae8780b344c40908e585792dd8719 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4eeae8780b344c40908e585792dd8719&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4eeae8780b344c40908e585792dd8719 = L.map(
#                 &quot;map_4eeae8780b344c40908e585792dd8719&quot;,
#                 {
#                     center: [40.7127281, -74.0060152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0737477ea7331f3b859ee74bc440c739 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4eeae8780b344c40908e585792dd8719);
#
#
#             var circle_marker_46d18ace012f89cf15f81a5aea1832fd = L.circleMarker(
#                 [40.89470517661, -73.847200520549],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4eeae8780b344c40908e585792dd8719);
#
#
#         var popup_64c3743acc06556843f116d0408274a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_33d9cf2e0fdcd0c1af7c550c11cb4f8f = $(`&lt;div id=&quot;html_33d9cf2e0fdcd0c1af7c550c11cb4f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0: Bronx-Wakefield 6210.0 cases 113.0 deaths&lt;/div&gt;`)[0];
#             popup_64c3743acc06556843f116d0408274a3.setContent(html_33d9cf2e0fdcd0c1af7c550c11cb4f8f);
#
#
#         circle_marker_46d18ace012f89cf15f81a5aea1832fd.bindPopup(popup_64c3743acc06556843f116d0408274a3)
#         ;
#
#
#
#
#             var circle_marker_eb8090434f65a1b03c5b2604bb7ff58a = L.circleMarker(
#                 [40.8742941930301, -73.829939108124],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4eeae8780b344c40908e585792dd8719);
#
#
#         var popup_6371a9f66b7945ef86180d8cbb3b7965 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0e646430b38df5ef8ddcb06a44be70f8 = $(`&lt;div id=&quot;html_0e646430b38df5ef8ddcb06a44be70f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 2: Bronx-Co-op City 8654.0 cases 292.0 deaths&lt;/div&gt;`)[0];
#             popup_6371a9f66b7945ef86180d8cbb3b7965.setContent(html_0e646430b38df5ef8ddcb06a44be70f8);
#
#
#         circle_marker_eb8090434f65a1b03c5b2604bb7ff58a.bindPopup(popup_6371a9f66b7945ef86180d8cbb3b7965)
#         ;
#
#
#
#
#             var circle_marker_5347796a8fe670d04159967b6a855e9e = L.circleMarker(
#                 [40.8954374269038, -73.9056425959168],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4eeae8780b344c40908e585792dd8719);
#
#
#         var popup_9ac0191bdb7424246dbb426798888081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ace8e930d5f18d42ca01f9f34ae1d951 = $(`&lt;div id=&quot;html_ace8e930d5f18d42ca01f9f34ae1d951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0: Bronx-Fieldston 706.0 cases 21.0 deaths&lt;/div&gt;`)[0];
#             popup_9ac0191bdb7424246dbb426798888081.setContent(html_ace8e930d5f18d42ca01f9f34ae1d951);
#
#
#         circle_marker_5347796a8fe670d04159967b6a855e9e.bindPopup(popup_9ac0191bdb7424246dbb426798888081)
#         ;
#
#
#
#
#             var circle_marker_eecb705ec843889930d4f0bb10071a41 = L.circleMarker(
#                 [40.8908344938913, -73.9125854610857],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpa

# %% [markdown]
# ### use DBScan

# %%
#define params space with eps and min_sample
eps = [0.2, 0.4, 0.5, 0.6, 0.8]
min_samples = [3, 4, 5]

# %%
# #combine different values of the parameters and visualize the clusters
# import itertools

# for element in itertools.product(eps, min_samples):
#     db = DBSCAN(eps=element[0],
#                 min_samples=element[1],
#                 metric='euclidean')
#     y_db = db.fit_predict(X)
#     plt.title(f'eps = {element[0]},  min_samples = {element[1]}')
#     plot_clusters(X,y_db)

# %% [markdown]
# ## Segmentation of NYC neighborhoods
#
# The goal of this project is to segment the neighborhoods of New York City into separate clusters and examine the information about them. For clustering, We can use any available information **except** demographic and economic indicators. We don't want to segment them based on those and we want to keep them for the **profiling of clusters** to see if there are any important economic differences between the created clusters.

# %% [markdown]
# ### Modeling
#
# Use different attributes and clustering techniques and compare the created clusters:
#
# - clustering only on covid cases and death count features
# - clustering only on hospital beds features
# - clustering only on location
# - combination of all
#
# **Questions:**
# 1. Which clustering is the best?
# 2. How are neighborhoods split when we select only 2 clusters?
# 3. Are there any differences in housing and rental costs in different clusters?

# %% [markdown]
# ## How are neighborhoods split when we select only 2 clusters?

# %%
##K-Means Clustering

km1 = KMeans(n_clusters=2, # check neighbourhood split with only 2 clusters
            n_init=10, # how many initial runs
            random_state=0) #For reproducibility

## fit and predict 
X = scaled_data

y_km1 = km1.fit_predict(X)

# %%
#make a deep copy of the NYC_covid dataframe
NYC_2clusters_df = NYC_covid.copy()

#get the cluster each neighborhood belongs to
NYC_2clusters_df['cluster'] = y_km1

#check dataframe
NYC_2clusters_df.head()
# Out:
#   Neighbourhood borough  longitude   latitude  Population  ZIP_CODE  MODZCTA  \
# 0     Wakefield   Bronx -73.847201  40.894705     29158.0     10466    10466
# 1    Co-op City   Bronx -73.829939  40.874294     43752.0     10475    10475
# 2     Fieldston   Bronx -73.905643  40.895437      3292.0     10471    10471
# 3     Riverdale   Bronx -73.912585  40.890834     48049.0     10463    10463
# 4   Kingsbridge   Bronx -73.902818  40.881687     10669.0     10463    10463
#
#    COVID_CONFIRMED_CASE_RATE  COVID_CONFIRMED_DEATH_RATE  TOTAL_COVID_TESTS  \
# 0                   21299.93                      388.44              65398
# 1                   19781.32                      669.20              37537
# 2                   21453.73                      640.27              23352
# 3                   21106.29                      508.69              66378
# 4                   21106.29                      508.69              66378
#
#    COVID_CONFIRMED_CASE_COUNT  COVID_CONFIRMED_DEATH_COUNT  cluster
# 0                      6210.0                        113.0        0
# 1                      8654.0                        292.0        0
# 2                       706.0                         21.0        0
# 3                     10141.0                        244.0        0
# 4                      2251.0                         54.0        0

# %%
#check cluster 1
NYC_2clusters_df[NYC_2clusters_df['cluster']==1]
# Out:
#                  Neighbourhood    borough  longitude   latitude  Population  \
# 8                   Baychester      Bronx -73.835798  40.866858     63345.0
# 33                   Bay Ridge   Brooklyn -74.030621  40.625801     79371.0
# 34                 Bensonhurst   Brooklyn -73.995180  40.611009    104934.0
# 35                 Sunset Park   Brooklyn -74.010316  40.645103    126000.0
# 39                    Flatbush   Brooklyn -73.958401  40.636326    105804.0
# 40               Crown Heights   Brooklyn -73.943291  40.670829    143000.0
# 41               East Flatbush   Brooklyn -73.936103  40.641718    135619.0
# 44                 Brownsville   Brooklyn -73.910235  40.663950     58300.0
# 45                Williamsburg   Brooklyn -73.958115  40.707144    151308.0
# 46                    Bushwick   Brooklyn -73.925258  40.698116    129239.0
# 51                    Canarsie   Brooklyn -73.902093  40.635564     83693.0
# 56                Borough Park   Brooklyn -73.990498  40.633131    153470.0
# 60   Prospect Lefferts Gardens   Brooklyn -73.954899  40.658420     99287.0
# 65          Washington Heights  Manhattan -73.936900  40.851903    143879.0
# 69                 East Harlem  Manhattan -73.944182  40.792249    115921.0
# 70             Upper East Side  Manhattan -73.960508  40.775639    124231.0
# 72             Upper West Side  Manhattan -73.977059  40.787658    214744.0
# 74                     Midtown  Manhattan -73.981669  40.754691    104753.0
# 78             Lower East Side  Manhattan -73.980890  40.717807     72957.0
# 84             Jackson Heights     Queens -73.882821  40.751981    108152.0
# 85                    Elmhurst     Queens -73.881656  40.744049     88427.0
# 87                      Corona     Queens -73.856825  40.742382    109695.0
# 88                Forest Hills     Queens -73.844475  40.725264     83728.0
# 90               Richmond Hill     Queens -73.831833  40.697947     62982.0
# 96                   Woodhaven     Queens -73.858110  40.689887     56674.0
# 97            South Ozone Park     Queens -73.809865  40.668550     75878.0
# 114               Far Rockaway     Queens -73.754980  40.603134     50058.0
# 124               North Corona     Queens -73.857518  40.754071    109695.0
# 134                      Rugby   Brooklyn -73.926882  40.655572    135619.0
# 148                    Erasmus   Brooklyn -73.948177  40.646926    135619.0
# 155                  Concourse      Bronx -73.915589  40.834284     75371.0
# 157             Sheepshead Bay   Brooklyn -73.943186  40.586890     64518.0
# 158                 Kensington   Brooklyn -73.980421  40.642382     72413.0
# 162              Cypress Hills   Brooklyn -73.876616  40.682391     59010.0
# 163              East New York   Brooklyn -73.880699  40.669926     91958.0
# 170                  City Line   Brooklyn -73.867976  40.678570     94469.0
# 180                    Astoria     Queens -73.915654  40.768509     78793.0
# 181                   Flushing     Queens -73.831773  40.764454     72008.0
# 211                    Wingate   Brooklyn -73.937187  40.660947    110300.0
# 239          Concourse Village      Bronx -73.915847  40.824780     75371.0
# 263         Bedford Stuyvesant   Brooklyn -73.941785  40.687232    157530.0
# 268                 South Side   Brooklyn -73.958001  40.710861    156393.0
# 269             Central Harlem  Manhattan -73.943211  40.815976    197052.0
# 272             Jamaica Center     Queens -73.796902  40.704657     53751.0
# 277                Lefrak City     Queens -73.862525  40.736075     91510.0
# 280       Forest Hills Gardens     Queens -73.841022  40.714611     83728.0
# 298          Broadway Junction   Brooklyn -73.903317  40.677861     97518.0
#
#      ZIP_CODE  MODZCTA  COVID_CONFIRMED_CASE_RATE  COVID_CONFIRMED_DEATH_RATE  \
# 8       10469    10469                   21364.15                      706.45
# 33      11209    11209                   23217.26                      361.40
# 34      11204    11204                   22076.22                      371.01
# 35      11220    11220                   25480.29                      353.10
# 39      11226    11226                   21553.06                      487.90
# 40      11213    11213                   23778.17                      450.46
# 41      11203    11203                   21773.36                      521.04
# 44      11212    11212                   27450.08                      593.51
# 45      11206    11206                   24075.67                      350.59
# 46      11206    11206                   24075.67                      350.59
# 51      11236    11236                   21427.72                      487.04
# 56      11204    11204                   22076.22                      371.01
# 60      11225    11225                   19216.29                      403.38
# 65      10032    10032                   19696.72                      417.12
# 69      10029    10029                   24216.10                      484.50
# 70      10021    10021                   15899.54                      224.52
# 72      10023    10023                   19372.81                      168.33
# 74      10001    10001                   23836.52                      184.70
# 78      10002    10002                   22479.28                      475.29
# 84      11370    11370                   24514.33                      330.42
# 85      11373    11373                   27235.62                      445.14
# 87      11368    11368                   24864.60                      529.13
# 88      11375    11375                   20619.78                      475.68
# 90      11418    11418                   25344.81                      409.73
# 96      11421    11421                   29573.40                      461.93
# 97      11420    11420                   24339.89                      418.10
# 114     11691    11691                   26600.33                      804.71
# 124     11368    11368                   24864.60                      529.13
# 134     11203    11203                   21773.36                      521.04
# 148     11203    11203                   21773.36                      521.04
# 155     10451    10451                   26512.06                      519.35
# 157     11229    11229                   24811.01                      411.82
# 158     11218    11218                   22418.80                      395.97
# 162     11207    11207                   25965.99                      463.88
# 163     11207    11207                   25965.99                      463.88
# 170     11207    11207                   25965.99                      463.88
# 180     11101    11101                   26602.02                      236.18
# 181     11354    11354                   21358.02                      882.81
# 211     11203    11203                   21773.36                      521.04
# 239     10451    10451                   26512.06                      519.35
# 263     11205    11205                   21254.12                      211.77
# 268     11206    11206                   24075.67                      350.59
# 269     10037    10037                   22728.40                      490.54
# 272     11432    11432                   23193.26                      622.17
# 277     11368    11368                   24864.60                      529.13
# 280     11375    11375                   20619.78                      475.68
# 298     11207    11207                   25965.99                      463.88
#
#      TOTAL_COVID_TESTS  COVID_CONFIRMED_CASE_COUNT  \
# 8                66872                     13533.0
# 33               64926                     18427.0
# 34               76567                     23165.0
# 35               93606                     32105.0
# 39               95017                     22803.0
# 40               69425                     34002.0
# 41               69622                     29528.0
# 44               80142                     16003.0
# 45               92227                     36428.0
# 46               92227                     31115.0
# 51               85941                     17933.0
# 56               76567                     33880.0
# 60               54761                     19079.0
# 65               56169                     28339.0
# 69               80986                     28071.0
# 70               46485                     19752.0
# 72               72322                     41601.0
# 74               54175                     24969.0
# 78               78460                     16400.0
# 84               30671                     26512.0
# 85              100090                     24083.0
# 87              116077                     27275.0
# 88               65145                     17264.0
# 90               35654                     15962.0
# 96               39495                     16760.0
# 97               44347                     18468.0
# 114              66752                     13315.0
# 124             116077                     27275.0
# 134              69622                     29528.0
# 148              69622                     29528.0
# 155              50433                     19982.0
# 157              75463                     16007.0
# 158              80721                     16234.0
# 162              92331                     15322.0
# 163              92331                     23877.0
# 170              92331                     24529.0
# 180              53716                     20960.0
# 181              52412                     15379.0
# 211              69622                     24016.0
# 239              50433                     19982.0
# 263              49349                     33481.0
# 268              92227                     37652.0
# 269              21785                     44786.0
# 272              62179                     12466.0
# 277             116077                     22753.0
# 280              65145                     17264.0
# 298              92331                     25321.0
#
#      COVID_CONFIRMED_DEATH_COUNT  cluster
# 8                          447.0        1
# 33                         286.0        1
# 34                         389.0        1
# 35                         444.0        1
# 39                         516.0        1
# 40                         644.0        1
# 41                         706.0        1
# 44                         346.0        1
# 45                         530.0        1
# 46                         453.0        1
# 51                         407.0        1
# 56                         569.0        1
# 60                         400.0        1
# 65                         600.0        1
# 69                         561.0        1
# 70                         278.0        1
# 72                         361.0        1
# 74                         193.0        1
# 78                         346.0        1
# 84                         357.0        1
# 85                         393.0        1
# 87                         580.0        1
# 88                         398.0        1
# 90                         258.0        1
# 96                         261.0        1
# 97                         317.0        1
# 114                        402.0        1
# 124                        580.0        1
# 134                        706.0        1
# 148                        706.0        1
# 155                        391.0        1
# 157                        265.0        1
# 158                        286.0        1
# 162                        273.0        1
# 163                        426.0        1
# 170                        438.0        1
# 180                        186.0        1
# 181                        635.0        1
# 211                        574.0        1
# 239                        391.0        1
# 263                        333.0        1
# 268                        548.0        1
# 269                        966.0        1
# 272                        334.0        1
# 277                        484.0        1
# 280                        398.0        1
# 298                        452.0        1

# %%
#visualize neighbourhood clusters
neighborhood_cluster_viz(num_clusters = 2, df = NYC_2clusters_df, colours=['red', 'green'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_277c8597b28f81ac38f289ffa90f888f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_277c8597b28f81ac38f289ffa90f888f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_277c8597b28f81ac38f289ffa90f888f = L.map(
#                 &quot;map_277c8597b28f81ac38f289ffa90f888f&quot;,
#                 {
#                     center: [40.7127281, -74.0060152],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d80b1d77568a6b5c0226c00552580b26 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_277c8597b28f81ac38f289ffa90f888f);
#
#
#             var circle_marker_f82b750d6945306396f30e769c5417ef = L.circleMarker(
#                 [40.89470517661, -73.847200520549],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_277c8597b28f81ac38f289ffa90f888f);
#
#
#             var circle_marker_3a70325e4acaf2d94cfac92656f38e16 = L.circleMarker(
#                 [40.8742941930301, -73.829939108124],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_277c8597b28f81ac38f289ffa90f888f);
#
#
#             var circle_marker_ab2d6851ac37dceefed1190ecb518f26 = L.circleMarker(
#                 [40.8954374269038, -73.9056425959168],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_277c8597b28f81ac38f289ffa90f888f);
#
#
#             var circle_marker_a0b5fb83d3e366788aa54acfeacf85e3 = L.circleMarker(
#                 [40.8908344938913, -73.9125854610857],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_277c8597b28f81ac38f289ffa90f888f);
#
#
#             var circle_marker_45e4160c0ac6bc513e150510fd650cc1 = L.circleMarker(
#                 [40.8816873712052, -73.902817987246],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_277c8597b28f81ac38f289ffa90f888f);
#
#
#             var circle_marker_b25d5dbf6941486b021ad56f924b8c52 = L.circleMarker(
#                 [40.8765507787996, -73.9106596586298],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_277c8597b28f81ac38f289ffa90f888f);
#
#
#             var circle_marker_88d30067e74cd41e119924b8c1c6c15b = L.circleMarker(
#                 [40.8772241559945, -73.8793907395681],
#                 {&quot;bubblingM

# %% [markdown]
# ### Evaluation
#
# 1. Check the segmentation evaluation metrics:
#     - inertia
#     - silhoutte score
# 2. How did you come up with the correct number of clusters?
# 3. Is there any relationship between the clusters and economic indicators? If yes, what does it mean?
#
# You are required to share the file containing all NYC neighborhoods together with cluster_id with LighthouseLabs.

# %%
##evaluate kmeans segmentation using silhoutte score
labels = km.labels_
metrics.silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.5540184805052945

# %%
##evaluate kmeans segmentation for 2 clusters using silhoutte score
labels = km1.labels_
metrics.silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.6892109331295113

# %%
##evaluate hierarchical segmentation using silhoutte score
labels = ac.labels_
metrics.silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.5634425593143282
